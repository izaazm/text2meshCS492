# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import sys
root_path = '/content/drive/My Drive/project/implementation'
sys.path.append(root_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install Dependencies

# %%
# install depencdencies
# !pip install trimesh==3.9.33 einops==0.3.2 scipy==1.5.2 \
             siren-pytorch==0.1.5 usd-core==21.8 \
             torch==1.9.0 torchtext==0.10.0 torchvision==0.10.0 cython==0.29.20 \
             git+https://github.com/openai/CLIP.git@04f4dc2ca1ed0acc9893bd1a3b526a7e02c4bb10 \
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/CLIP.git@04f4dc2ca1ed0acc9893bd1a3b526a7e02c4bb10
#   Cloning https://github.com/openai/CLIP.git (to revision 04f4dc2ca1ed0acc9893bd1a3b526a7e02c4bb10) to /tmp/pip-req-build-iem42i_7
#   Running command git clone -q https://github.com/openai/CLIP.git /tmp/pip-req-build-iem42i_7
#   Running command git rev-parse -q --verify 'sha^04f4dc2ca1ed0acc9893bd1a3b526a7e02c4bb10'
#   Running command git fetch -q https://github.com/openai/CLIP.git 04f4dc2ca1ed0acc9893bd1a3b526a7e02c4bb10
#   Running command git checkout -q 04f4dc2ca1ed0acc9893bd1a3b526a7e02c4bb10
# Collecting trimesh==3.9.33
#   Downloading trimesh-3.9.33-py3-none-any.whl (638 kB)
#      |████████████████████████████████| 638 kB 7.4 MB/s
# Collecting einops==0.3.2
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Collecting scipy==1.5.2
#   Downloading scipy-1.5.2-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 1.1 MB/s
# Collecting siren-pytorch==0.1.5
#   Downloading siren_pytorch-0.1.5-py3-none-any.whl (3.9 kB)
# Collecting usd-core==21.8
#   Downloading usd_core-21.8-cp37-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 1.1 MB/s
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 2.7 kB/s
# Collecting torchtext==0.10.0
#   Downloading torchtext-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 27.2 MB/s
# Collecting torchvision==0.10.0
#   Downloading torchvision-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 104.5 MB/s
# Collecting cython==0.29.20
#   Downloading Cython-0.29.20-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 51.5 MB/s
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.2 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from clip==1.0) (2019.12.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from clip==1.0) (4.64.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from trimesh==3.9.33) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from trimesh==3.9.33) (57.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.10.0) (2.23.0)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.10.0) (7.1.2)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->clip==1.0) (0.2.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (2.10)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369091 sha256=b6cd548ced3852e98d7287dc32ff040979ccbc6d4eaf457e6620a56daaf5d4c2
#   Stored in directory: /root/.cache/pip/wheels/24/97/92/93e96763c0fc100c9720cf66c17846a7b98011aa19ba00dc0d
# Successfully built clip
# Installing collected packages: torch, torchvision, ftfy, einops, usd-core, trimesh, torchtext, siren-pytorch, scipy, cython, clip
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.12.0
#     Uninstalling torchtext-0.12.0:
#       Successfully uninstalled torchtext-0.12.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: cython
#     Found existing installation: Cython 0.29.30
#     Uninstalling Cython-0.29.30:
#       Successfully uninstalled Cython-0.29.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.9.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed clip-1.0 cython-0.29.20 einops-0.3.2 ftfy-6.1.1 scipy-1.5.2 siren-pytorch-0.1.5 torch-1.9.0 torchtext-0.10.0 torchvision-0.10.0 trimesh-3.9.33 usd-core-21.8

# %%
# install kaolin if not installed already
get_kaolin = True
root_path = '/content/drive/MyDrive/project/implementation/codes'
if get_kaolin:
    # %cd {root_path}
    # %ls
    # %cd ..
    # !git clone --recursive https://github.com/NVIDIAGameWorks/kaolin
    # %cd kaolin
    # !git checkout v0.10.0
    # !python setup.py develop
    
# %cd {root_path}
# Out:
# /content/drive/MyDrive/project/implementation
# codes/
# Cloning into 'kaolin'...
# remote: Enumerating objects: 3715, done.
# remote: Counting objects: 100% (298/298), done.
# remote: Compressing objects: 100% (190/190), done.
# remote: Total 3715 (delta 140), reused 257 (delta 106), pack-reused 3417
# Receiving objects: 100% (3715/3715), 85.05 MiB | 18.50 MiB/s, done.
# Resolving deltas: 100% (1922/1922), done.
# Checking out files: 100% (430/430), done.
# Submodule 'third_party/cub' (https://github.com/NVIDIA/cub) registered for path 'third_party/cub'
# Cloning into '/content/drive/MyDrive/project/implementation/kaolin/third_party/cub'...
# remote: Enumerating objects: 31124, done.
# remote: Counting objects: 100% (207/207), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 31124 (delta 123), reused 141 (delta 84), pack-reused 30917
# Receiving objects: 100% (31124/31124), 16.65 MiB | 7.65 MiB/s, done.
# Resolving deltas: 100% (26362/26362), done.
# Submodule path 'third_party/cub': checked out '499a7bad3416fcc71a7c50351d6b3cdbf3fbbc27'
# /content/drive/MyDrive/project/implementation/kaolin
# error: Your local changes to the following files would be overwritten by checkout:
# 	tests/integration/experimental/dash3d/start_dash3d.sh
# Please commit your changes or stash them before you switch branches.
# Aborting
# Warning: passing language='c++' to cythonize() is deprecated. Instead, put "# distutils: language=c++" in your .pyx or .pxd file(s)
# Compiling kaolin/cython/ops/mesh/triangle_hash.pyx because it changed.
# Compiling kaolin/cython/ops/conversions/mise.pyx because it changed.
# [1/2] Cythonizing kaolin/cython/ops/conversions/mise.pyx
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/drive/MyDrive/project/implementation/kaolin/kaolin/cython/ops/conversions/mise.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: kaolin/cython/ops/conversions/mise.pyx:90:33: Not all members given for struct 'Voxel'
# warning: kaolin/cython/ops/conversions/mise.pyx:90:33: Not all members given for struct 'Voxel'
# warning: kaolin/cython/ops/conversions/mise.pyx:284:33: Not all members given for struct 'Voxel'
# warning: kaolin/cython/ops/conversions/mise.pyx:284:33: Not all members given for struct 'Voxel'
# [2/2] Cythonizing kaolin/cython/ops/mesh/triangle_hash.pyx
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/drive/MyDrive/project/implementation/kaolin/kaolin/cython/ops/mesh/triangle_hash.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running develop
# running egg_info
# creating kaolin.egg-info
# writing kaolin.egg-info/PKG-INFO
# writing dependency_links to kaolin.egg-info/dependency_links.txt
# writing requirements to kaolin.egg-info/requires.txt
# writing top-level names to kaolin.egg-info/top_level.txt
# writing manifest file 'kaolin.egg-info/SOURCES.txt'
# /usr/local/lib/python3.7/dist-packages/torch/utils/cpp_extension.py:370: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'kaolin.egg-info/SOURCES.txt'
# running build_ext
# building 'kaolin._C' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/kaolin
# creating build/temp.linux-x86_64-3.7/kaolin/csrc
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/metrics
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/ops
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/mesh_to_spc
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/unbatched_mcube
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/ops/mesh
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/render
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh
# creating build/temp.linux-x86_64-3.7/kaolin/csrc/render/spc
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/bindings.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/bindings.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# In file included from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Parallel.h:140:0,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include/torch/utils.h:3,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include/torch/nn/cloneable.h:5,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include/torch/nn.h:3,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include/torch/all.h:13,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/torch/extension.h:4,
#                  from kaolin/csrc/bindings.cpp:16:
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/ParallelOpenMP.h:87:0: warning: ignoring #pragma omp parallel [-Wunknown-pragmas]
#  #pragma omp parallel for if ((end - begin) >= grain_size)
#
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/metrics/sided_distance.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/metrics/sided_distance.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/metrics/unbatched_triangle_distance.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/metrics/unbatched_triangle_distance.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/packed_simple_sum.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/packed_simple_sum.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/tile_to_packed.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/tile_to_packed.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/conversions/mesh_to_spc/mesh_to_spc.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/mesh_to_spc/mesh_to_spc.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/mesh/mesh_intersection.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/mesh/mesh_intersection.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# kaolin/csrc/ops/mesh/mesh_intersection.cpp: In function ‘void kaolin::unbatched_mesh_intersection_cuda(at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor)’:
# kaolin/csrc/ops/mesh/mesh_intersection.cpp:70:64: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#      UnbatchedMeshIntersectionKernelLauncher(points.data<float>(), verts_1.data<float>(),
#                                                                 ^
# In file included from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Context.h:4,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/ATen.h:9,
#                  from kaolin/csrc/ops/mesh/mesh_intersection.cpp:15:
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:501:7: note: declared here
#    T * data() const {
#        ^~~~
# kaolin/csrc/ops/mesh/mesh_intersection.cpp:70:87: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#      UnbatchedMeshIntersectionKernelLauncher(points.data<float>(), verts_1.data<float>(),
#                                                                                        ^
# In file included from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Context.h:4,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/ATen.h:9,
#                  from kaolin/csrc/ops/mesh/mesh_intersection.cpp:15:
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:501:7: note: declared here
#    T * data() const {
#        ^~~~
# kaolin/csrc/ops/mesh/mesh_intersection.cpp:71:65: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#                                              verts_2.data<float>(),verts_3.data<float>(), points.size(0),
#                                                                  ^
# In file included from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Context.h:4,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/ATen.h:9,
#                  from kaolin/csrc/ops/mesh/mesh_intersection.cpp:15:
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:501:7: note: declared here
#    T * data() const {
#        ^~~~
# kaolin/csrc/ops/mesh/mesh_intersection.cpp:71:87: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#                                              verts_2.data<float>(),verts_3.data<float>(), points.size(0),
#                                                                                        ^
# In file included from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Context.h:4,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/ATen.h:9,
#                  from kaolin/csrc/ops/mesh/mesh_intersection.cpp:15:
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:501:7: note: declared here
#    T * data() const {
#        ^~~~
# kaolin/csrc/ops/mesh/mesh_intersection.cpp:73:62: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#                                              ints.data<float>());
#                                                               ^
# In file included from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Tensor.h:3:0,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Context.h:4,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/ATen.h:9,
#                  from kaolin/csrc/ops/mesh/mesh_intersection.cpp:15:
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:501:7: note: declared here
#    T * data() const {
#        ^~~~
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/convolution.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/convolution.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/feature_grids.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/feature_grids.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# In file included from /usr/local/lib/python3.7/dist-packages/torch/include/c10/core/DeviceType.h:8:0,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/c10/core/Device.h:3,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/c10/core/Allocator.h:6,
#                  from /usr/local/lib/python3.7/dist-packages/torch/include/ATen/ATen.h:7,
#                  from kaolin/csrc/ops/spc/feature_grids.cpp:16:
# kaolin/csrc/ops/spc/feature_grids.cpp: In function ‘at::Tensor kaolin::to_dense_forward(at::Tensor, int, at::Tensor, at::Tensor)’:
# kaolin/csrc/ops/spc/feature_grids.cpp:67:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    TORCH_CHECK(num_features == psize);
#                ~~~~~~~~~~~~~^~~~
# /usr/local/lib/python3.7/dist-packages/torch/include/c10/macros/Macros.h:195:64: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                 ^~~~
# /usr/local/lib/python3.7/dist-packages/torch/include/c10/util/Exception.h:430:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#        ^~~~~~~~~~~~~~~~~~~~~
# kaolin/csrc/ops/spc/feature_grids.cpp:67:3: note: in expansion of macro ‘TORCH_CHECK’
#    TORCH_CHECK(num_features == psize);
#    ^~~~~~~~~~~
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/point_utils.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/point_utils.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/query.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/query.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/spc.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/spc.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/render/mesh/deftet.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/deftet.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/render/mesh/dibr_soft_mask.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/dibr_soft_mask.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/render/mesh/rasterization.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/rasterization.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/render/spc/raytrace.cpp -o build/temp.linux-x86_64-3.7/kaolin/csrc/render/spc/raytrace.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/metrics/sided_distance_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/metrics/sided_distance_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/metrics/unbatched_triangle_distance_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/metrics/unbatched_triangle_distance_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/packed_simple_sum_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/packed_simple_sum_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/tile_to_packed_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/tile_to_packed_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/conversions/mesh_to_spc/mesh_to_spc_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/mesh_to_spc/mesh_to_spc_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.cu: In function ‘void kaolin::allocateTextures(at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor)’:
# kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.cu:46:69: warning: ‘cudaError_t cudaBindTexture(size_t*, const texture<T, dim, readMode>&, const void*, const cudaChannelFormatDesc&, size_t) [with T = unsigned int; int dim = 1; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; size_t = long unsigned int]’ is deprecated [-Wdeprecated-declarations]
#    cudaBindTexture(0, triTex, d_triTable.data_ptr<int>(), channelDesc);
#                                                                      ^
# /usr/local/cuda/include/cuda_runtime.h:1293:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTexture(
#                                                      ^~~~~~~~~~~~~~~
# kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.cu:49:91: warning: ‘cudaError_t cudaBindTexture(size_t*, const texture<T, dim, readMode>&, const void*, const cudaChannelFormatDesc&, size_t) [with T = unsigned int; int dim = 1; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; size_t = long unsigned int]’ is deprecated [-Wdeprecated-declarations]
#    cudaBindTexture(0, numUniqueVertsTex, d_numUniqueVertsTable.data_ptr<int>(), channelDesc);
#                                                                                            ^
# /usr/local/cuda/include/cuda_runtime.h:1293:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTexture(
#                                                      ^~~~~~~~~~~~~~~
# kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.cu:52:87: warning: ‘cudaError_t cudaBindTexture(size_t*, const texture<T, dim, readMode>&, const void*, const cudaChannelFormatDesc&, size_t) [with T = unsigned int; int dim = 1; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; size_t = long unsigned int]’ is deprecated [-Wdeprecated-declarations]
#    cudaBindTexture(0, numTrianglesTex, d_numTrianglesTable.data_ptr<int>(), channelDesc);
#                                                                                        ^
# /usr/local/cuda/include/cuda_runtime.h:1293:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTexture(
#                                                      ^~~~~~~~~~~~~~~
# kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.cu:55:93: warning: ‘cudaError_t cudaBindTexture(size_t*, const texture<T, dim, readMode>&, const void*, const cudaChannelFormatDesc&, size_t) [with T = unsigned int; int dim = 1; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; size_t = long unsigned int]’ is deprecated [-Wdeprecated-declarations]
#    cudaBindTexture(0, numPartialVertsTex, d_numPartialVertsTable.data_ptr<int>(), channelDesc);
#                                                                                              ^
# /usr/local/cuda/include/cuda_runtime.h:1293:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTexture(
#                                                      ^~~~~~~~~~~~~~~
# kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.cu:58:83: warning: ‘cudaError_t cudaBindTexture(size_t*, const texture<T, dim, readMode>&, const void*, const cudaChannelFormatDesc&, size_t) [with T = unsigned int; int dim = 1; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; size_t = long unsigned int]’ is deprecated [-Wdeprecated-declarations]
#    cudaBindTexture(0, vertsOrderTex, d_vertsOrderTable.data_ptr<int>(), channelDesc);
#                                                                                    ^
# /usr/local/cuda/include/cuda_runtime.h:1293:53: note: declared here
#  static __CUDA_DEPRECATED __inline__ __host__ cudaError_t cudaBindTexture(
#                                                      ^~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime.h: In instantiation of ‘cudaError_t cudaBindTexture(size_t*, const texture<T, dim, readMode>&, const void*, const cudaChannelFormatDesc&, size_t) [with T = unsigned int; int dim = 1; cudaTextureReadMode readMode = (cudaTextureReadMode)0; cudaError_t = cudaError; size_t = long unsigned int]’:
# kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.cu:46:69:   required from here
# /usr/local/cuda/include/cuda_runtime.h:1301:25: warning: ‘cudaError_t cudaBindTexture(size_t*, const textureReference*, const void*, const cudaChannelFormatDesc*, size_t)’ is deprecated [-Wdeprecated-declarations]
#    return ::cudaBindTexture(offset, &tex, devPtr, &desc, size);
#         ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/include/cuda_runtime_api.h:7897:46: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaBindTexture(size_t *offset, const struct textureReference *texref, const void *devPtr, const struct cudaChannelFormatDesc *desc, size_t size __dv(UINT_MAX));
#                                               ^~~~~~~~~~~~~~~
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/mesh/mesh_intersection_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/mesh/mesh_intersection_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/convolution_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/convolution_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/feature_grids_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/feature_grids_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/generate_points.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/generate_points.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/minkowski_conv.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/minkowski_conv.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# /usr/local/cuda/bin/nvcc -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.7m -c kaolin/csrc/ops/spc/point_utils_cuda.cu -o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/point_utils_cuda.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -O3 -DWITH_CUDA -DTHRUST_IGNORE_CUB_VERSION_CHECK -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_60,code=compute_60 -gencode=arch=compute_60,code=sm_60 -std=c++14
# kaolin/csrc/ops/spc/point_utils_cuda.cu: In lambda function:
# kaolin/csrc/ops/spc/point_utils_cuda.cu:206:46: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#      AT_DISPATCH_FLOATING_TYPES_AND_HALF(feats_in.type(), "interpolate_trilinear_cuda", ([&] {
#                                               ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:338:1: note: declared here
#    DeprecatedTypeProperties & type() const {
#  ^ ~~
# kaolin/csrc/ops/spc/point_utils_cuda.cu:206:101: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#      AT_DISPATCH_FLOATING_TYPES_AND_HALF(feats_in.type(), "interpolate_trilinear_cuda", ([&] {
#                                                                                                      ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Dispatch.h:121:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#  ^~~~~~~~~~~
# kaolin/csrc/ops/spc/point_utils_cuda.cu: In lambda function:
# kaolin/csrc/ops/spc/point_utils_cuda.cu:231:44: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#      AT_DISPATCH_FLOATING_TYPES_AND_HALF(coeffs.type(), "coords_to_trilinear_cuda", ([&] {
#                                             ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:338:1: note: declared here
#    DeprecatedTypeProperties & type() const {
#  ^ ~~
# kaolin/csrc/ops/spc/point_utils_cuda.cu:231:99: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#      AT_DISPATCH_FLOATING_TYPES_AND_HALF(coeffs.type(), "coords_to_trilinear_cuda", ([&] {
#                                                                                                    ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Dispatch.h:121:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#  ^~~~~~~~~~~
# ...
#          AT_DISPATCH_FLOATING_TYPES_AND_HALF(feats_in.type(), "cumsum_cuda", ([&] {
#                                               ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:338:1: note: declared here
#    DeprecatedTypeProperties & type() const {
#  ^ ~~
# kaolin/csrc/render/spc/raytrace_cuda.cu:671:101: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#          AT_DISPATCH_FLOATING_TYPES_AND_HALF(feats_in.type(), "cumsum_cuda", ([&] {
#                                                                                                      ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Dispatch.h:121:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#  ^~~~~~~~~~~
# kaolin/csrc/render/spc/raytrace_cuda.cu: In lambda function:
# kaolin/csrc/render/spc/raytrace_cuda.cu:699:46: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#          AT_DISPATCH_FLOATING_TYPES_AND_HALF(feats_in.type(), "cumprod_reverse_cuda", ([&] {
#                                               ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:338:1: note: declared here
#    DeprecatedTypeProperties & type() const {
#  ^ ~~
# kaolin/csrc/render/spc/raytrace_cuda.cu:699:101: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#          AT_DISPATCH_FLOATING_TYPES_AND_HALF(feats_in.type(), "cumprod_reverse_cuda", ([&] {
#                                                                                                      ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Dispatch.h:121:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#  ^~~~~~~~~~~
# kaolin/csrc/render/spc/raytrace_cuda.cu: In lambda function:
# kaolin/csrc/render/spc/raytrace_cuda.cu:709:46: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#          AT_DISPATCH_FLOATING_TYPES_AND_HALF(feats_in.type(), "cumprod_cuda", ([&] {
#                                               ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/core/TensorBody.h:338:1: note: declared here
#    DeprecatedTypeProperties & type() const {
#  ^ ~~
# kaolin/csrc/render/spc/raytrace_cuda.cu:709:101: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#          AT_DISPATCH_FLOATING_TYPES_AND_HALF(feats_in.type(), "cumprod_cuda", ([&] {
#                                                                                                      ^
# /usr/local/lib/python3.7/dist-packages/torch/include/ATen/Dispatch.h:121:1: note: declared here
#  inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#  ^~~~~~~~~~~
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/kaolin
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/kaolin/csrc/bindings.o build/temp.linux-x86_64-3.7/kaolin/csrc/metrics/sided_distance.o build/temp.linux-x86_64-3.7/kaolin/csrc/metrics/unbatched_triangle_distance.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/packed_simple_sum.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/tile_to_packed.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/mesh_to_spc/mesh_to_spc.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/mesh/mesh_intersection.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/convolution.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/feature_grids.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/point_utils.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/query.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/spc.o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/deftet.o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/dibr_soft_mask.o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/rasterization.o build/temp.linux-x86_64-3.7/kaolin/csrc/render/spc/raytrace.o build/temp.linux-x86_64-3.7/kaolin/csrc/metrics/sided_distance_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/metrics/unbatched_triangle_distance_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/packed_simple_sum_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/tile_to_packed_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/mesh_to_spc/mesh_to_spc_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/conversions/unbatched_mcube/unbatched_mcube_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/mesh/mesh_intersection_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/convolution_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/feature_grids_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/generate_points.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/minkowski_conv.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/point_utils_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/query_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/ops/spc/scan_octrees.o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/deftet_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/dibr_soft_mask_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/render/mesh/rasterization_cuda.o build/temp.linux-x86_64-3.7/kaolin/csrc/render/spc/raytrace_cuda.o -L/usr/local/lib/python3.7/dist-packages/torch/lib -L/usr/local/cuda/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart_static -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.7/kaolin/_C.so
# building 'kaolin.ops.mesh.triangle_hash' extension
# creating build/temp.linux-x86_64-3.7/kaolin/cython
# creating build/temp.linux-x86_64-3.7/kaolin/cython/ops
# creating build/temp.linux-x86_64-3.7/kaolin/cython/ops/mesh
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/include/python3.7m -c kaolin/cython/ops/mesh/triangle_hash.cpp -o build/temp.linux-x86_64-3.7/kaolin/cython/ops/mesh/triangle_hash.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=triangle_hash -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1969:0,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from kaolin/cython/ops/mesh/triangle_hash.cpp:656:
# /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# kaolin/cython/ops/mesh/triangle_hash.cpp: In function ‘PyObject* __pyx_f_6kaolin_3ops_4mesh_13triangle_hash_12TriangleHash_query(__pyx_obj_6kaolin_3ops_4mesh_13triangle_hash_TriangleHash*, __Pyx_memviewslice, int)’:
# kaolin/cython/ops/mesh/triangle_hash.cpp:2880:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for (__pyx_t_6 = 0; __pyx_t_6 < __pyx_t_19; __pyx_t_6+=1) {
#                        ~~~~~~~~~~^~~~~~~~~~~~
# kaolin/cython/ops/mesh/triangle_hash.cpp:2889:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for (__pyx_t_6 = 0; __pyx_t_6 < __pyx_t_19; __pyx_t_6+=1) {
#                        ~~~~~~~~~~^~~~~~~~~~~~
# creating build/lib.linux-x86_64-3.7/kaolin/ops
# creating build/lib.linux-x86_64-3.7/kaolin/ops/mesh
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/kaolin/cython/ops/mesh/triangle_hash.o -L/usr/local/lib/python3.7/dist-packages/torch/lib -lc10 -ltorch -ltorch_cpu -ltorch_python -o build/lib.linux-x86_64-3.7/kaolin/ops/mesh/triangle_hash.so
# building 'kaolin.ops.conversions.mise' extension
# creating build/temp.linux-x86_64-3.7/kaolin/cython/ops/conversions
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/torch/include -I/usr/local/lib/python3.7/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.7/dist-packages/torch/include/TH -I/usr/local/lib/python3.7/dist-packages/torch/include/THC -I/usr/include/python3.7m -c kaolin/cython/ops/conversions/mise.cpp -o build/temp.linux-x86_64-3.7/kaolin/cython/ops/conversions/mise.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=mise -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# kaolin/cython/ops/conversions/mise.cpp: In function ‘PyObject* __pyx_pf_6kaolin_3ops_11conversions_4mise_4MISE_8get_points(__pyx_obj_6kaolin_3ops_11conversions_4mise_MISE*)’:
# kaolin/cython/ops/conversions/mise.cpp:3476:35: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for (__pyx_t_10 = 0; __pyx_t_10 < __pyx_t_9; __pyx_t_10+=1) {
#                         ~~~~~~~~~~~^~~~~~~~~~~
# kaolin/cython/ops/conversions/mise.cpp: In function ‘void __pyx_f_6kaolin_3ops_11conversions_4mise_4MISE_subdivide_voxels(__pyx_obj_6kaolin_3ops_11conversions_4mise_MISE*)’:
# kaolin/cython/ops/conversions/mise.cpp:3703:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for (__pyx_t_9 = 0; __pyx_t_9 < __pyx_t_11; __pyx_t_9+=1) {
#                        ~~~~~~~~~~^~~~~~~~~~~~
# kaolin/cython/ops/conversions/mise.cpp:3712:62: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      __pyx_t_12 = (((__pyx_v_self->voxels[__pyx_v_idx]).level == __pyx_v_self->depth) != 0);
# kaolin/cython/ops/conversions/mise.cpp:3744:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#    for (__pyx_t_9 = 0; __pyx_t_9 < __pyx_t_11; __pyx_t_9+=1) {
#                        ~~~~~~~~~~^~~~~~~~~~~~
# kaolin/cython/ops/conversions/mise.cpp:3753:62: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      __pyx_t_12 = (((__pyx_v_self->voxels[__pyx_v_idx]).level == __pyx_v_self->depth) != 0);
# kaolin/cython/ops/conversions/mise.cpp: At global scope:
# kaolin/cython/ops/conversions/mise.cpp:15782:18: warning: ‘PyObject* __pyx_convert__to_py_struct____pyx_t_6kaolin_3ops_11conversions_4mise_Vector3D(__pyx_t_6kaolin_3ops_11conversions_4mise_Vector3D)’ defined but not used [-Wunused-function]
#  static PyObject* __pyx_convert__to_py_struct____pyx_t_6kaolin_3ops_11conversions_4mise_Vector3D(struct __pyx_t_6kaolin_3ops_11conversions_4mise_Vector3D s) {
#                   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# creating build/lib.linux-x86_64-3.7/kaolin/ops/conversions
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/kaolin/cython/ops/conversions/mise.o -L/usr/local/lib/python3.7/dist-packages/torch/lib -lc10 -ltorch -ltorch_cpu -ltorch_python -o build/lib.linux-x86_64-3.7/kaolin/ops/conversions/mise.so
# copying build/lib.linux-x86_64-3.7/kaolin/_C.so -> kaolin
# copying build/lib.linux-x86_64-3.7/kaolin/ops/mesh/triangle_hash.so -> kaolin/ops/mesh
# copying build/lib.linux-x86_64-3.7/kaolin/ops/conversions/mise.so -> kaolin/ops/conversions
# Creating /usr/local/lib/python3.7/dist-packages/kaolin.egg-link (link to .)
# Adding kaolin 0.11.0 to easy-install.pth file
#
# Installed /content/drive/MyDrive/project/implementation/kaolin
# Processing dependencies for kaolin==0.11.0
# Searching for Pillow>=8.0.0
# Reading https://pypi.org/simple/Pillow/
# Downloading https://files.pythonhosted.org/packages/96/82/0cbf62676f9d64dd0e73e1667ec6cc189bd52051ee85558081167010fdfa/Pillow-9.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=8a66fe50386162df2da701b3722781cbe90ce043e7d53c1fd6bd801bca6b48d4
# Best match: Pillow 9.1.1
# Processing Pillow-9.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing Pillow-9.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding Pillow 9.1.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/Pillow-9.1.1-py3.7-linux-x86_64.egg
# Searching for usd-core==21.8
# Best match: usd-core 21.8
# Adding usd-core 21.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tqdm==4.64.0
# Best match: tqdm 4.64.0
# Adding tqdm 4.64.0 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for scipy==1.5.2
# Best match: scipy 1.5.2
# Adding scipy 1.5.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.21.6
# Best match: numpy 1.21.6
# Adding numpy 1.21.6 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for kaolin==0.11.0
# /content/drive/MyDrive/project/implementation
# /content/drive/MyDrive/project/implementation/codes

# %%
# !python3 main.py
# Out:
# neural_style_field(
#   (pe_layer): progessive_encoding()
#   (base): ModuleList(
#     (0): fourier_feature()
#     (1): progessive_encoding()
#     (2): Linear(in_features=515, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=256, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=256, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=256, out_features=256, bias=True)
#     (11): ReLU()
#   )
#   (mlp_rgb): ModuleList(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=3, bias=True)
#   )
#   (mlp_normal): ModuleList(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=1, bias=True)
#   )
# )
#   0% 0/750 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1794: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py:594: UserWarning: torch.lstsq is deprecated in favor of torch.linalg.lstsq and will be removed in a future PyTorch release.
# torch.linalg.lstsq has reversed arguments and does not return the QR decomposition in the returned tuple (although it returns other information about the problem).
# To get the qr decomposition consider using torch.linalg.qr.
# The returned solution in torch.lstsq stored the residuals of the solution in the last m - n columns of the returned value whenever m > n. In torch.linalg.lstsq, the residuals in the field 'residuals' of the returned named tuple.
# The unpacking of the solution, as in
# X, _ = torch.lstsq(B, A).solution[:A.size(1)]
# should be replaced with
# X = torch.linalg.lstsq(A, B).solution (Triggered internally at  /pytorch/aten/src/ATen/LegacyTHFunctionsCPU.cpp:389.)
#   res = torch.lstsq(b_matrix, a_matrix)[0]
# iter 0/750 || loss=-0.2661
#  13% 100/750 [02:02<13:23,  1.24s/it]iter 100/750 || loss=-0.2729
#  27% 200/750 [04:05<11:18,  1.23s/it]iter 200/750 || loss=-0.2964
#  40% 300/750 [06:08<09:16,  1.24s/it]iter 300/750 || loss=-0.2930
#  53% 400/750 [08:10<07:12,  1.24s/it]iter 400/750 || loss=-0.2900
#  67% 500/750 [10:11<05:07,  1.23s/it]iter 500/750 || loss=-0.2903
#  80% 600/750 [12:14<03:04,  1.23s/it]iter 600/750 || loss=-0.2920
#  93% 700/750 [14:16<01:01,  1.23s/it]iter 700/750 || loss=-0.2976
# 100% 750/750 [15:17<00:00,  1.22s/it]
# Traceback (most recent call last):
#   File "main.py", line 350, in <module>
#     pred_color, pred_normal = net(input)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1051, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "main.py", line 140, in forward
#     x = layer(x)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1051, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "main.py", line 87, in forward
#     out = 2 * np.pi * torch.matmul(x, self.B)
# TypeError: matmul(): argument 'input' (position 1) must be Tensor, not builtin_function_or_method
